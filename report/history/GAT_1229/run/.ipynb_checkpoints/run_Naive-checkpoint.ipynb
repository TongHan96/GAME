# %%
# !pip install torch_geometric
# !pip install tensorflow
# !pip install keras
# !pip install zipfile
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-2.0.0+cu118.html

# %%
import os
os.chdir('/home/doz128/GAME/src')

# %%
# %run main.py --want_TOP1 72.0 --path '/home/doz128/GAME' --epochs 5 --lr 1e-5 --AA 1 --BB 1 --lambd 0.1 --drop_out 0.1
# Out:
# SandR_Model(
#   (S_Model): GATModel(
#     (gat1): GATLayer(
#       (gat_conv): GATConv(1536, 1024, heads=2)
#       (batch_norm): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (activation): ReLU()
#     )
#     (gat2): GATLayer(
#       (gat_conv): GATConv(2048, 1024, heads=3)
#       (batch_norm): BatchNorm1d(3072, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (activation): ReLU()
#     )
#     (linear): Linear(in_features=3072, out_features=256, bias=True)
#   )
# )
# ------------------------Epoch: 001-----------------------
# 2024
# Accuracy    TOP1 59.58%    TOP5 73.91%    TOP10 76.98%    TOP20 80.53%
# EPOCH: 001     LOSS: 202995.9688
# ------------------------Epoch: 002-----------------------
