# %%
import os
os.chdir('/home/doz128/GAME_0407/src')

# %%
# %run main.py --path '/home/doz128/GAME_0407/' --epochs 500 --drop_out 0.5 --scale_sppmi 0.1 --lr 5e-6 --hidden_features 768 --DEVICE 'cuda' --path_origin 'sim_step' --api_key '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'
# Out:
# load aligned sppmi embedding!
# load similarity embedding!
# inst_encoder(
#   (GAT_together): GATLayer(
#     (gat_conv): GATConv(1536, 768, heads=2)
#     (batch_norm): BatchNorm1d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU()
#   )
#   (Linear): Linear(in_features=1536, out_features=512, bias=True)
# )
# sppmi_pos_loss: 196.10623168945312
# sppmi_neg_loss: 875.912109375
# SapBERT: 0.065	CODER: 0.17	MGB SPPMI: 0.429	VA SPPMI: 0.366	UPMC SPPMI: 0.206	BCH SPPMI: 0.184	GAME: 0.257
# SapBERT: 0.349	CODER: 0.257	MGB SPPMI: 0.597	VA SPPMI: 0.537	UPMC SPPMI: 0.283	BCH SPPMI: 0.359	GAME: 0.592
# SapBERT: -0.182	CODER: 0.168	MGB SPPMI: 0.635	VA SPPMI: 0.464	UPMC SPPMI: 0.288	BCH SPPMI: 0.397	GAME: 0.678
# SapBERT: 0.174	CODER: 0.29	MGB SPPMI: 0.136	VA SPPMI: 0.207	UPMC SPPMI: 0.19	BCH SPPMI: -0.071	GAME: 0.162
# SapBERT: 0.04	CODER: 0.278	MGB SPPMI: 0.281	VA SPPMI: 0.331	UPMC SPPMI: 0.288	BCH SPPMI: 0.023	GAME: 0.144
# ...
