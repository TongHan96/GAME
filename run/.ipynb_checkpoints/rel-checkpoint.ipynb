# %%
import os
os.chdir('/home/doz128/GAME_0726/src')

# %%
# %run main.py --path '/home/doz128/GAME_0726/' --epochs 500 --drop_out 0.5 --EDGE_ALL --scale_sppmi 0.1 --lr 1e-6 --hidden_features 768 --DEVICE 'cuda' --path_origin '2024-08-28 20:07:37' --align_path '2024-08-23 14:19:22' --api_key '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'
# Out:
# load aligned sppmi embedding!
# 2024-08-29 19:14:48,328 - INFO - inst_encoder(
#   (GAT_together): GATLayer(
#     (gat_conv): GATConv(1536, 768, heads=2)
#     (batch_norm): BatchNorm1d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU()
#   )
#   (Linear): Linear(in_features=1536, out_features=512, bias=True)
# )
# load similarity embedding!
# All logs will be saved to /home/doz128/GAME_0726//output/2024-08-29 19:14:43/2024-08-29 19:14:43.log
# undirected_edge_index.shape = torch.Size([2, 608578])
# 50738
# 50738
# sppmi_pos_loss: 0.116829514503479
# sppmi_neg_loss: 0.3689366579055786
# SapBERT: 0.042	CODER: 0.18	BGE: 0.233	OPENAI: 0.513	MGB SPPMI: 0.318	VA SPPMI: 0.274	UPMC SPPMI: 0.2	BCH SPPMI: 0.199	Duke SPPMI: -0.011	MIMIC SPPMI: -0.247	Bor SPPMI: 0.273	GAME: 0.45
# ...
