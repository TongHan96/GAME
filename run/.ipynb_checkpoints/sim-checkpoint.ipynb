# %%
import os
os.chdir('/home/doz128/GAME_0726/src')

# %%
# %run main.py --path '/home/doz128/GAME_0726/' --rmax 256 --epochs 500 --scale_OTOL 30 --drop_out 0.5 --scale_sppmi 0.1 --lr 1e-6 --hidden_features 768 --DEVICE 'cuda' --EDGE_ALL --api_key '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' --align_path '2024-08-23 14:19:22'
# Out:
# load aligned sppmi embedding!
# 2024-08-28 20:07:42,163 - INFO - inst_encoder(
#   (GAT_together): GATLayer(
#     (gat_conv): GATConv(1536, 768, heads=2)
#     (batch_norm): BatchNorm1d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU()
#   )
#   (Linear): Linear(in_features=1536, out_features=256, bias=True)
# )
# All logs will be saved to /home/doz128/GAME_0726//output/2024-08-28 20:07:37/2024-08-28 20:07:37.log
# undirected_edge_index.shape = torch.Size([2, 608578])
# 2024-08-28 20:19:37,622 - INFO - Accuracy    TOP1 75.38%    TOP5 86.32%    TOP10 89.11%    TOP20 91.50%
# SapBERT: 0.062	CODER: 0.232	BGE: 0.247	OPENAI: 0.539	MGB SPPMI: 0.324	VA SPPMI: 0.299	UPMC SPPMI: 0.223	BCH SPPMI: 0.22	Duke SPPMI: 0.025	MIMIC SPPMI: -0.206	Bor SPPMI: 0.287	GAME: 0.085
# ...
