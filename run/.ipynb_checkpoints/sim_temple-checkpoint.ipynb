# %%
import os
os.chdir('/home/doz128/GAME_0407/src')

# %%
# %run main.py --path '/home/doz128/GAME_0407/' --epochs 500 --drop_out 0.5 --scale_sppmi 0.1 --lr 5e-6 --hidden_features 768 --DEVICE 'cuda' --EDGE_ALL --api_key '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'
# Out:
# load aligned sppmi embedding!
# inst_encoder(
#   (GAT_together): GATLayer(
#     (gat_conv): GATConv(1536, 768, heads=2)
#     (batch_norm): BatchNorm1d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU()
#   )
#   (Linear): Linear(in_features=1536, out_features=256, bias=True)
# )
# Accuracy    TOP1 68.33%    TOP5 87.09%    TOP10 89.26%    TOP20 91.08%
# SapBERT: 0.068	CODER: 0.175	MGB SPPMI: 0.432	VA SPPMI: 0.38	UPMC SPPMI: 0.229	BCH SPPMI: 0.186	GAME: 0.111
# SapBERT: 0.364	CODER: 0.269	MGB SPPMI: 0.609	VA SPPMI: 0.55	UPMC SPPMI: 0.293	BCH SPPMI: 0.378	GAME: 0.479
# SapBERT: -0.191	CODER: 0.169	MGB SPPMI: 0.639	VA SPPMI: 0.466	UPMC SPPMI: 0.284	BCH SPPMI: 0.42	GAME: 0.425
# SapBERT: 0.168	CODER: 0.289	MGB SPPMI: 0.164	VA SPPMI: 0.225	UPMC SPPMI: 0.21	BCH SPPMI: -0.048	GAME: -0.039
# SapBERT: 0.033	CODER: 0.285	MGB SPPMI: 0.285	VA SPPMI: 0.327	UPMC SPPMI: 0.31	BCH SPPMI: 0.033	GAME: -0.101
# ...
